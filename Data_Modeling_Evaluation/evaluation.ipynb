# %%
# Model Success

'''
R^2 measurng success of models

Linear model

Adv:
linear relationship

Disadv:
no linar relationship
''' 

'''
Polynomial model

Adv:
non linear relationship between the variables

Disadv:
when there's a non-optimal degree in the regression
'''

'''
Support vector regression

Adv:
build different models with different kernels

Disadv:
when there's occurence of outliers in the data (data scaling not done properly)
'''

'''
Decision tree

Adv:
resilient to outliers and intuitive to visualise

Disadv:
prone to overfitting with smaller dataset (yield lower score in new data)
'''

'''
Random Forest

Adv:
overfitting is reduced due to aggregations (such as taking the mean)

Disadv:
hinders a simplistic visualisation
'''
